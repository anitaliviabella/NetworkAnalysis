# %% [markdown]
# ### Pre-processing
#
# #### In the code below I've imported the original file in python evnviroment as a dataframe.
# #### I've decided to remove childid, childfirstname and childlastname, merging together the columns in two new column:
#
# #### - full-name: childfirstname + childlastname, in order to obtain the full name of the child, this is usefull if we want to do some queries for a specific case.
#
# #### - identifier: childid + childfirstname + childlastname, this in order to create a unique identifier, it might be usefull for the newtork, in order to create nodes and prevent also homonymy.

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("dataset/original-file.csv", encoding='latin-1')

#create 'full name' column 
df["full-name"] = df["childfirstname"].astype(str) + ' ' + df["childlastname"]

#Create a new column 'identifier' which concatenates the first three columns:
df['identifier'] = df['childid'].astype(str) + '-' + df['childfirstname'] + '-' + df['childlastname']

#Remove the columns
df.drop(['childid', 'childfirstname', 'childlastname'], axis=1, inplace=True)

# Sostituire i NaN con "Not available"
df = df.replace(to_replace=np.nan, value="NotAvailable")


# Save the update dataframe in another 
df.to_csv('merged-file.csv', index=False)
df
# Out:
#           birthdate     sex      race     haircolor      eyecolor  \
# 0     11/28/85 0:00    Male     White        Blonde          Blue
# 1      6/23/87 0:00    Male     White     Lt. Brown         Brown
# 2       7/6/82 0:00  Female     Black         Black         Brown
# 3     10/18/94 0:00    Male  Hispanic         Sandy          Blue
# 4      7/18/79 0:00  Female  Hispanic         Black         Brown
# ...             ...     ...       ...           ...           ...
# 2829    2/5/00 0:00  Female     White  NotAvailable  NotAvailable
# 2830    3/1/00 0:00    Male     White  NotAvailable  NotAvailable
# 2831    7/6/00 0:00  Female     Black         Black         Brown
# 2832  12/13/99 0:00    Male     White         Brown         Brown
# 2833  10/13/99 0:00  Female     White           Red         Green
#
#       height (inches)  weight (lbs) missingreporteddate missingfromdate  \
# 0                  26            17        7/16/86 0:00    7/15/86 0:00
# ...

# %% [markdown]
# #### Apply some statistics

# %%
df.info() #specific info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2834 entries, 0 to 2833
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   birthdate            2834 non-null   object
#  1   sex                  2834 non-null   object
#  2   race                 2834 non-null   object
#  3   haircolor            2834 non-null   object
#  4   eyecolor             2834 non-null   object
#  5   height (inches)      2834 non-null   int64
#  6   weight (lbs)         2834 non-null   int64
#  7   missingreporteddate  2834 non-null   object
#  8   missingfromdate      2834 non-null   object
#  9   missingfromcity      2834 non-null   object
#  10  missingfromstate     2834 non-null   object
#  11  missingfromcountry   2834 non-null   object
#  12  ncmeccasenumber      2834 non-null   int64
#  13  casetype             2834 non-null   object
#  14  postercontact        2834 non-null   object
# ...

# %%
#females count
females = df.query('sex == "Female"')
females_count = females.value_counts()
females_count
# Out:
# birthdate     sex     race              haircolor     eyecolor      height (inches)  weight (lbs)  missingreporteddate  missingfromdate  missingfromcity  missingfromstate  missingfromcountry  ncmeccasenumber  casetype              postercontact                                                                       posterurl                                   full-name                identifier
# 1/1/00 0:00   Female  Biracial          Brown         Brown         65               102           11/22/16 1:17        11/21/16 0:00    Columbus         OH                United States       1282203          Endangered Runaway    Columbus Police Department (Ohio) 1-614-645-4545                                    www.missingkids.org/poster/NCMC/1282203/1/  Cheyenne Reynolds        581611-Cheyenne-Reynolds          1
# ...

# %%
#males count
males = df.query('sex == "Male"')
males_count = males.value_counts()
males_count
# Out:
# birthdate     sex   race      haircolor     eyecolor      height (inches)  weight (lbs)  missingreporteddate  missingfromdate  missingfromcity  missingfromstate  missingfromcountry  ncmeccasenumber  casetype              postercontact                                                   posterurl                                   full-name             identifier
# 1/1/00 0:00   Male  Hispanic  Black         Brown         65               120           9/13/16 12:06        4/19/16 13:00    Colleyville      TX                United States       1276599          Endangered Runaway    Grapevine Police Department (Texas) 1-817-410-8127              www.missingkids.org/poster/NCMC/1276599/1/  Jorge Sosa            574267-Jorge-Sosa              1
# ...

# %% [markdown]
# ### Category:Missing American children: https://en.wikipedia.org/wiki/Category:Missing_American_children
# ### see if the cases are present in the DataFrame.

# %%
#EXAMPLE OF CHILD FOUND 

child_name_to_find = "Etan Patz"
# Use the query method to find the child by full name
result = df.query('`full-name` == @child_name_to_find')

# Check if any matching rows were found
if not result.empty:
    print("Child found:")
    print(result)
else:
    print("Child not found in the DataFrame.")
# Out:
# Child found:
#         birthdate   sex   race  haircolor eyecolor  height (inches)  \
# 135  10/9/72 0:00  Male  White  Lt. Brown     Blue               40
#
#      weight (lbs) missingreporteddate missingfromdate missingfromcity  \
# 135            50        6/15/84 0:00    5/25/79 0:00        New York
#
#     missingfromstate missingfromcountry  ncmeccasenumber  \
# 135               NY      United States           603392
#
#                  casetype                                      postercontact  \
# 135  Non Family Abduction  New York Police Department (New York) - Missin...
#
#                                      posterurl  full-name     identifier
# 135  www.missingkids.org/poster/NCMC/603392/1/  Etan Patz  229-Etan-Patz

# %%
#EXAMPLE OF CHILD NOT FOUND
child_name_to_find = "Ann Burr"
# Use the query method to find the child by full name
result = df.query('`full-name` == @child_name_to_find')

# Check if any matching rows were found
if not result.empty:
    print("Child found:")
    print(result)
else:
    print("Child not found in the DataFrame.")
# Out:
# Child not found in the DataFrame.

# %%
#EXAMPLE OF CHILD NOT FOUND
child_name_to_find = "Amber Swartz"
# Use the query method to find the child by full name
result = df.query('`full-name` == @child_name_to_find')

# Check if any matching rows were found
if not result.empty:
    print("Child found:")
    print(result)
else:
    print("Child not found in the DataFrame.")
# Out:
# Child found:
#         birthdate     sex   race haircolor eyecolor  height (inches)  \
# 165  8/19/80 0:00  Female  White    Blonde     Blue               48
#
#      weight (lbs) missingreporteddate missingfromdate missingfromcity  \
# 165            62         6/5/88 0:00     6/3/88 0:00          Pinole
#
#     missingfromstate missingfromcountry  ncmeccasenumber  \
# 165               CA      United States           767759
#
#                  casetype                                      postercontact  \
# 165  Non Family Abduction  Pinole Police Department (California) Missing ...
#
#                                      posterurl     full-name        identifier
# 165  www.missingkids.org/poster/NCMC/767759/1/  Amber Swartz  271-Amber-Swartz

# %% [markdown]
# **Cases Present in the Data Frame:**
#
# - [Disappearance of Tammy Belanger](https://en.wikipedia.org/wiki/Disappearance_of_Tammy_Belanger) — Never found
# - [Murders of Lauria Bible and Ashley Freeman](https://en.wikipedia.org/wiki/Murders_of_Lauria_Bible_and_Ashley_Freeman) —
# - [Disappearance of Brianna Maitland](https://en.wikipedia.org/wiki/Disappearance_of_Brianna_Maitland) no
# - [Martin family disappearance](https://en.wikipedia.org/wiki/Martin_family_disappearance) no
# - [Disappearance of Dannette and Jeannette Millbrook](https://en.wikipedia.org/wiki/Disappearance_of_Dannette_and_Jeannette_Millbrook) no
# - [Kidnapping of Mary Agnes Moroney](https://en.wikipedia.org/wiki/Kidnapping_of_Mary_Agnes_Moroney) no
# - [Disappearance of Jared Negrete](https://en.wikipedia.org/wiki/Disappearance_of_Jared_Negrete) no
# - [Disappearance of Bianca Piper](https://en.wikipedia.org/wiki/Disappearance_of_Bianca_Piper) no
# - [Disappearance of Beverly Potts](https://en.wikipedia.org/wiki/Disappearance_of_Beverly_Potts) no
# - [Disappearance of Andy Puglisi](https://en.wikipedia.org/wiki/Disappearance_of_Andy_Puglisi) no
# - [Rachel Trlica](https://en.wikipedia.org/wiki/Rachel_Trlica) no
# - *[Rocio Sperry](https://en.wikipedia.org/wiki/Rocio_Sperry) no
# - [Kidnapping of Charley Ross](https://en.wikipedia.org/wiki/Kidnapping_of_Charley_Ross) no
# - [Disappearance of Susan Smalley and Stacie Madison](https://en.wikipedia.org/wiki/Disappearance_of_Susan_Smalley_and_Stacie_Madison) sì
# - [Sodder children disappearance](https://en.wikipedia.org/wiki/Sodder_children_disappearance) no
# - *[Rima Traxler](https://en.wikipedia.org/wiki/Rima_Traxler) no*
# - [Disappearance of LeeAnna Warner](https://en.wikipedia.org/wiki/Disappearance_of_LeeAnna_Warner) no
# - [Disappearance of Rilya Wilson](https://en.wikipedia.org/wiki/Disappearance_of_Rilya_Wilson) no

# %% [markdown]
# ### Here I am creating a new df with only the selected cases, filtring the previous one. I added also the wikipedia link of the case in the section "wiki-link" as well as the "wiki-category" that all of them have in common.

# %%
import pandas as pd

# Supponiamo che il tuo DataFrame originale sia chiamato 'df'
# Ecco la lista dei nomi dei casi selezionati
selected_cases = [ 
    "Tammy Belanger",
    "Lauria Bible",
    "Ashley Freeman",
    "Amy Billig",
    "Melissa Brannen",
    "Jeremy Bright",
    "Anthonette Cayedito",
    "Perry Cohen",
    "Austin Stephanos",
    "Kiplyn Davis",
    "Asha Degree",
    "Shaina Kirkpatrick",
    "Shausha Henson",
    "Christie Farni",
    "Arianna Fitts",
    "Mary Trlica", 
    "Lisa Wilson",
    "Julie Moseley",
    "Erin Foster",
    "Jeremy Bechtel",
    "Margaret Fox",
    "Derrick Engebretson",
    "Michaela Garecht",
    "Ann Gotlib",
    "Kyron Horman",
    "Lisa Irwin",
    "Reed Jeppson",
    "Sofia Juarez",
    "Christopher Kerze",
    "Katherine"
    "Sheila Lyon",
    "Cherrie Mahan",
    "Nyleen Marshall",
    "Dennis Martin",
    "Melanie Melanson",
    "Sky Metalwala",
    "Morgan Nick",
    "Leigh Occhi",
    "Etan Patz",
    "Timmothy Pitzen",
    "Laureen Rahn",
    "Ayla Reynolds",
    "Sarah Skiba",
    "Patricia Spencer",
    "Pamela Hobley",
    "Amber Swartz",
    "Alissa Turney",
    "Adele Wells",
    "Marjorie West",
    "Kelly Wilson",
    "Sara Wood"
]

# Filtra il DataFrame originale in base ai casi selezionati
selected_df = df[df['full-name'].isin(selected_cases)]

# Aggiungi i link Wikipedia ai casi selezionati
selected_links = {
    "Tammy Belanger":"https://en.wikipedia.org/wiki/Disappearance_of_Tammy_Belanger",
    "Lauria Bible":"https://en.wikipedia.org/wiki/Murders_of_Lauria_Bible_and_Ashley_Freeman",
    "Ashley Freeman":"https://en.wikipedia.org/wiki/Murders_of_Lauria_Bible_and_Ashley_Freeman",
    "Amy Billig":"https://en.wikipedia.org/wiki/Disappearance_of_Amy_Billig",
    "Melissa Brannen":"https://en.wikipedia.org/wiki/Disappearance_of_Melissa_Brannen",
    "Jeremy Bright":"https://en.wikipedia.org/wiki/Disappearance_of_Jeremy_Bright",
    "Anthonette Cayedito":"https://en.wikipedia.org/wiki/Disappearance_of_Anthonette_Cayedito",
    "Perry Cohen":"https://en.wikipedia.org/wiki/Disappearance_of_Perry_Cohen_and_Austin_Stephanos",
    "Austin Stephanos":"https://en.wikipedia.org/wiki/Disappearance_of_Perry_Cohen_and_Austin_Stephanos",
    "Kiplyn Davis":"https://en.wikipedia.org/wiki/Murder_of_Kiplyn_Davis",
    "Asha Degree":"https://en.wikipedia.org/wiki/Disappearance_of_Asha_Degree",
    "Shaina Kirkpatrick":"https://en.wikipedia.org/wiki/Disappearances_of_Shaina_Kirkpatrick_and_Shausha_Henson",
    "Shausha Henson":"https://en.wikipedia.org/wiki/Disappearances_of_Shaina_Kirkpatrick_and_Shausha_Henson",
    "Christie Farni":"https://en.wikipedia.org/wiki/Disappearance_of_Christie_Farni",
    "Arianna Fitts":"https://en.wikipedia.org/wiki/Disappearance_of_Arianna_Fitts",
    "Mary Trlica":"https://en.wikipedia.org/wiki/Fort_Worth_missing_trio",
    "Lisa Wilson":"https://en.wikipedia.org/wiki/Fort_Worth_missing_trio",
    "Julie Moseley":"https://en.wikipedia.org/wiki/Fort_Worth_missing_trio",
    "Erin Foster":"https://en.wikipedia.org/wiki/Disappearance_of_Erin_Foster_and_Jeremy_Bechtel",
    "Jeremy Bechtel":"https://en.wikipedia.org/wiki/Disappearance_of_Erin_Foster_and_Jeremy_Bechtel",
    "Margaret Fox":"https://en.wikipedia.org/wiki/Disappearance_of_Margaret_Ellen_Fox",
    "Derrick Engebretson":"https://en.wikipedia.org/wiki/Disappearance_of_Derrick_Engebretson",
    "Michaela Garecht":"https://en.wikipedia.org/wiki/Michaela_Garecht",
    "Ann Gotlib":"https://en.wikipedia.org/wiki/Disappearance_of_Ann_Gotlib",
    "Kyron Horman":"https://en.wikipedia.org/wiki/Disappearance_of_Kyron_Horman",
    "Lisa Irwin":"https://en.wikipedia.org/wiki/Disappearance_of_Lisa_Irwin",
    "Reed Jeppson":"https://en.wikipedia.org/wiki/Disappearance_of_Reed_Jeppson",
    "Sofia Juarez":"https://en.wikipedia.org/wiki/Disappearance_of_Sofia_Juarez",
    "Christopher Kerze":"https://en.wikipedia.org/wiki/Disappearance_of_Christopher_Kerze",
    "Katherine Lyon":"https://en.wikipedia.org/wiki/Murders_of_Katherine_and_Sheila_Lyon",
    "Sheila Lyon":"https://en.wikipedia.org/wiki/Murders_of_Katherine_and_Sheila_Lyon",
    "Cherrie Mahan":"https://en.wikipedia.org/wiki/Disappearance_of_Cherrie_Mahan",
    "Nyleen Marshall":"https://en.wikipedia.org/wiki/Disappearance_of_Nyleen_Marshall",
    "Dennis Martin":"https://en.wikipedia.org/wiki/Dennis_L._Martin",
    "Melanie Melanson":"https://en.wikipedia.org/wiki/Melanie_Melanson",
    "Sky Metalwala" :"https://en.wikipedia.org/wiki/Disappearance_of_Sky_Metalwala",
    "Morgan Nick":"https://en.wikipedia.org/wiki/Disappearance_of_Morgan_Nick",
    "Leigh Occhi":"https://en.wikipedia.org/wiki/Disappearance_of_Leigh_Occhi",
    "Etan Patz":"https://en.wikipedia.org/wiki/Disappearance_of_Etan_Patz",
    "Timmothy Pitzen":"https://en.wikipedia.org/wiki/Disappearance_of_Timmothy_Pitzen",
    "Laureen Rahn":"https://en.wikipedia.org/wiki/Disappearance_of_Laureen_Rahn",
    "Ayla Reynolds":"https://en.wikipedia.org/wiki/Disappearance_of_Ayla_Reynolds",
    "Sarah Skiba":"https://en.wikipedia.org/wiki/Disappearances_of_Paul_and_Sarah_Skiba_and_Lorenzo_Chivers",
    "Patricia Spencer":"https://en.wikipedia.org/wiki/Disappearance_of_Patricia_Spencer_and_Pamela_Hobley",
    "Pamela Hobley":"https://en.wikipedia.org/wiki/Disappearance_of_Patricia_Spencer_and_Pamela_Hobley",
    "Amber Swartz":"https://en.wikipedia.org/wiki/Kidnapping_of_Amber_Swartz%E2%80%93Garcia",
    "Alissa Turney":"https://en.wikipedia.org/wiki/Disappearance_of_Alissa_Turney",
    "Adele Wells":"https://en.wikipedia.org/wiki/Disappearance_of_Adele_Marie_Wells",
    "Marjorie West":"https://en.wikipedia.org/wiki/Disappearance_of_Marjorie_West",
    "Kelly Wilson":"https://en.wikipedia.org/wiki/Disappearance_of_Kelly_Dae_Wilson",
    "Sara Wood":"https://en.wikipedia.org/wiki/Disappearance_of_Sara_Anne_Wood",

}

selected_df['wiki-link'] = selected_df['full-name'].map(selected_links)

# Crea una nuova colonna 'wiki-category' con il link specificato
selected_df['wiki-category'] = 'https://en.wikipedia.org/wiki/Category:Missing_American_children'
# Salva il DataFrame in un file CSV
selected_df.to_csv('dataset/selected_.csv', index=False)

# Sostituisci 'nome_del_tuo_file.csv' con il percorso e il nome del file CSV che desideri creare.


selected_df
# Out:
# /var/folders/zs/lq8vbm2x2_731j6yk99z0m940000gp/T/ipykernel_861/3708453164.py:118: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['wiki-link'] = selected_df['full-name'].map(selected_links)
# /var/folders/zs/lq8vbm2x2_731j6yk99z0m940000gp/T/ipykernel_861/3708453164.py:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['wiki-category'] = 'https://en.wikipedia.org/wiki/Category:Missing_American_children'
# ...
